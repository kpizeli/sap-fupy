# %%
from string import Template
import pandas as pd
from dotenv import load_dotenv
import requests
import os
import follow_up as fu
load_dotenv()
# Out:
# True

# %%
layout = Template("""
Olá, <@$ID_Slack>!
Temos um $tipo_documento aguardando a sua aprovação no SAP!
                  
:page_with_curl: Documento: $doc
:office: Fornecedor: $fornecedor
:dollar: Centro de Custo: $centro_custo       
---------------------------------------

Você pode acessar a tela de aprovação por esse <https://my434489.s4hana.cloud.sap/ui?sap-client=100#Shell-home|link>
Caso tenha alguma dúvida, fale com a <@U07PV73E891>
                  
""")

token = os.getenv('SLACK_BOT_TOKEN')

# %%
df = fu.limpeza_dados(pd)
df = fu.buscar_id_slack(df)
fu.enviar_mensagens(df, token, layout, requests)

# %%
df
# Out:
#    Empresa                       Nome do fornecedor       Tipo Documento  \
# 0     1435  LEXISNEXIS SERVICOS DE ANALISE DE RISCO  Contrato de Compras
# 1     1410        IFOOD BENEFICIOS E SERVICOS LTDA.  Contrato de Compras
# 2     1435  LIMA & FEIGELSON SOCIEDADE DE ADVOGADOS  Contrato de Compras
# 3     1435  LIMA & FEIGELSON SOCIEDADE DE ADVOGADOS  Contrato de Compras
# 4     1435  LIMA & FEIGELSON SOCIEDADE DE ADVOGADOS  Contrato de Compras
# 5     1435            LEE, BROCK, CAMARGO ADVOGADOS  Contrato de Compras
# 6     1435                               OPENAI INC  Contrato de Compras
#
#     Documento  Status Tarefa Centro de Custo Vencimento         Aprovadores  \
# 0  4600000419  Ag. Aprovação      2P5B290028 1899-12-30               ERROR
# 1  4600000429  Ag. Aprovação      2T5B511179 1899-12-30               ERROR
# 2  4600000449  Ag. Aprovação      2P5B290029 1899-12-30    Leticia Domingos
# 3  4600000449  Ag. Aprovação      2P5B290029 1899-12-30    Raimundo Marconi
# 4  4600000478  Ag. Aprovação      2P5B290029 1899-12-30  Fernando Montanari
# 5  4600000515  Ag. Aprovação      2P5B290029 1899-12-30  Fernando Montanari
# 6  4600000518  Ag. Aprovação      2P0A430074 1899-12-30  Fernando Montanari
#
#   ID do usuário     ID Slack
# 0           NaN          NaN
# 1           NaN          NaN
# 2  CB9980000072  U05LPGXM1A7
# 3  CB9980000166  U03B9M3MGDP
# 4  CB9980000043    U9LA2EFMK
# 5  CB9980000043    U9LA2EFMK
# 6  CB9980000043    U9LA2EFMK
